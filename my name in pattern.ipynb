# %%
str="SURENDRA"
print_S = [[" " for i in range(7)] for j in range(7)]
print_U = [[" " for i in range(7)] for j in range(7)]
print_R = [[" " for i in range(7)] for j in range(7)]
print_E = [[" " for i in range(7)] for j in range(7)]
print_N = [[" " for i in range(7)] for j in range(7)]
print_D = [[" " for i in range(7)] for j in range(7)]
print_R = [[" " for i in range(7)] for j in range(7)]
print_A = [[" " for i in range(7)] for j in range(7)]

#print S symbol
for row in range(7):
    for col in range(7):
        if (row==0 and col!=0) or (row==3 and (col!=0 and col!=6)) or (row==6 and col!=6) or (col==0 and (row>0 and row<3)) or (col==6 and (row>3 and row<6)):
            print_S[row][col]= "S"
            
#print U symbol
for row in range(7):
    for col in range(7):
        if ((col==0 or col==6) and row!=6) or (row==6 and (col!=0 and col!=6)):
            print_U[row][col]= "U"
            
# print R symbol
for row in range(7):
    for col in range(7):
        if (col==0)or (col==6 and row!=0 and row!=3 ) or ((row==0 or row==3 ) and (col>0 and col<6)):
            print_R[row][col]= "R"
            
#print E symbol
for row in range(7):
    for col in range(7):
        if (col==0) or ((row==0 or row==3 or row==6) and (col>0)):
            print_E[row][col]= "E"
            
#print N symbol
for row in range(7):
    for col in range(7):
        if (col==0 or col==6) or ((row==col) and (col>0 and col<6)):
            print_N[row][col]= "N"
            
#print D symbol
for row in range(7):
    for col in range(7):
        if (col==0) or (col==6 and (row!=0 and row!=6)) or (row==0 or row==6) and (col>0 and col<6):
            print_D[row][col]= "D"
            
            
# print R symbol
for row in range(7):
    for col in range(7):
        if (col==0)or (col==6 and row!=0 and row!=3 ) or ((row==0 or row==3 ) and (col>0 and col<6)):
            print_R[row][col]= "R"
            
# print A symbol
for row in range(7):
    for col in range(7):
        if ((col==0 or col==6) and row!=0) or ((row==0 or row==3) and (col>0 and col<6)):
             print_A[row][col]= "A"
                
                
                
for i in range(7):
    for j in range(7):
        print(print_S[i][j],end=" ")
    print(end="  ")
    for j in range(7):
        print(print_U[i][j],end=" ")
    print(end="  ")    
    for j in range(7):
        print(print_R[i][j],end=" ")
    print(end="  ") 
    for j in range(7):
        print(print_E[i][j],end=" ")
    print(end="  ")    
    for j in range(7):
        print(print_N[i][j],end=" ")
    print(end="  ")    
    for j in range(7):
        print(print_D[i][j],end=" ")
    print(end="  ")    
    for j in range(7):
        print(print_R[i][j],end=" ")
    print(end="  ")    
    for j in range(7):
        print(print_A[i][j],end=" ")
    print()
# Out:
#   S S S S S S   U           U   R R R R R R     E E E E E E E   N           N   D D D D D D     R R R R R R       A A A A A
# S               U           U   R           R   E               N N         N   D           D   R           R   A           A
# S               U           U   R           R   E               N   N       N   D           D   R           R   A           A
#   S S S S S     U           U   R R R R R R     E E E E E E E   N     N     N   D           D   R R R R R R     A A A A A A A
#             S   U           U   R           R   E               N       N   N   D           D   R           R   A           A
#             S   U           U   R           R   E               N         N N   D           D   R           R   A           A
# S S S S S S       U U U U U     R           R   E E E E E E E   N           N   D D D D D D     R           R   A           A
